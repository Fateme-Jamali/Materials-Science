# %%
import pandas as pd
dfA=pd.read_csv('40-random-cubic.csv')
dfB=pd.read_csv('GLLBSC_SOC_19-from-40-random-.csv')
dfA=dfA.set_index('StructureName')
dfB=dfB.set_index('A1A2BX3')
dfA
# Out:
#                      PredictionsLS_BG  PredictionsLAD_BG  Predictions_FE
# StructureName
# 3-Py_GUA_AgBr3               1.485215           1.291864       -1.244221
# Cs_i-BuA_AgBr3               1.449370           1.485346       -1.115036
# EA_FA_AgBr3                  1.295726           1.380524       -1.354082
# FA_TetraMA_AgBr3             1.677939           1.348388       -0.365480
# 3-Py_GUA_AgCl3               1.115363           1.186298       -1.196207
# EA_MA_AgCl3                  1.681813           1.537223       -1.640203
# FA_TiZ_AgCl3                 1.338470           1.519014       -0.920763
# TriMA_TetraMA_AgCl3          1.305093           1.347239       -1.182671
# EA_i-PA_AgI3                 1.778231           1.536215        0.190771
# HY_TiZ_AgI3                  1.998659           1.783320        0.247463
# IM_Az_AgI3                   1.789727           1.560188        0.469812
# TriMA_TiZ_AgI3               1.872680           1.640931        0.421454
# ...

# %%
dfnew=dfA.loc[dfB.index]

# %%
dfnew.to_csv('intersection.csv')
